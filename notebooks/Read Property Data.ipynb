# %%
import pandas as pd

# %%
df = pd.read_json('../data/raw/property.json')

# %%
df = df.transpose()

# %%
df[df["name"] == ""]
# Out:
#                                                    name cost_text type Area  \
# https://www.domain.com.au/1002-245-city-road-so...                        0
#
#                                                    coordinates  \
# https://www.domain.com.au/1002-245-city-road-so...      [0, 0]
#
#                                                                            rooms
# https://www.domain.com.au/1002-245-city-road-so...  [2 Beds, 2 Baths, 1 Parking]

# %%
df[df["cost_text"] == ""]
# Out:
#                                                    name cost_text type Area  \
# https://www.domain.com.au/1002-245-city-road-so...                        0
#
#                                                    coordinates  \
# https://www.domain.com.au/1002-245-city-road-so...      [0, 0]
#
#                                                                            rooms
# https://www.domain.com.au/1002-245-city-road-so...  [2 Beds, 2 Baths, 1 Parking]

# %%
df
# Out:
#                                                                                          name  \
# https://www.domain.com.au/56-selwyn-street-albi...           56 Selwyn Street Albion VIC 3020
# https://www.domain.com.au/1-3-robin-street-alto...           1/3 Robin Street Altona VIC 3018
# https://www.domain.com.au/34-hucker-street-arar...           34 Hucker Street Ararat VIC 3377
# https://www.domain.com.au/3-neylan-street-arara...            3 Neylan Street Ararat VIC 3377
# https://www.domain.com.au/8-suspension-street-a...        8 Suspension Street Ardeer VIC 3022
# ...                                                                                       ...
# https://www.domain.com.au/31-austin-road-seafor...            31 Austin Road Seaford VIC 3198
# https://www.domain.com.au/12-morobe-street-sorr...         12 Morobe Street Sorrento VIC 3943
# https://www.domain.com.au/7-278-kings-way-south...   7/278 Kings Way South Melbourne VIC 3205
# ...
